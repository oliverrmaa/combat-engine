# %%
import random as rand
import numpy as np


# Create the Character Class first
class Character(object):
    def __init__(self, name, health, attack, crit_rate, crit_mult, berserk_percent, pray_percent):
        self.name = name    
        self.health = health
        self.attack = attack
        self.crit_rate = crit_rate
        self.crit_mult = crit_mult
        self.berserk_percent = berserk_percent
        self.pray_percent = pray_percent
    

    def getname(self):
        return self.name

    def dead(self):
        if self.health < 0:
            return True
        return False
    
    def printstat(self):
        return self.health, self.attack, self.crit_rate, self.crit_mult, 

    def gen_attack (self, hp_init):
        if self.health < hp_init/10:
            if np.random.uniform() < self.crit_rate:
                attack_val = self.crit_mult*(self.attack + self.berserk_percent*self.attack)
            else: 
                attack_val = self.attack + self.berserk_percent*self.attack
        else:
            if np.random.uniform() < self.crit_rate:
                attack_val = self.crit_mult*self.attack
            else: 
                attack_val = self.attack
        return attack_val
    

    def gen_heal (self):
        health_val = self.health + self.pray_percent*self.health
        return health_val

    
# Create the function for simulating 1 battle
def sim_battle(c1, c2):
    c1hp_init = c1.health
    c2hp_init = c2.health
    
    turn_count = 0

    # this is the core loop of the game
    while not c1.dead() and not c2.dead():    
        c1a = c1.gen_attack(c1hp_init)
        c2a = c2.gen_attack(c2hp_init)
        c1h = c1.gen_heal()
        c2h = c2.gen_heal()
        
        turn_count += 1
        
        if np.random.uniform() < 0.5:
            c1.health = c1h - c2a
        else:
            c2.health = c2h - c1a
  
    # if someone gets defeated
    if c1.dead() and not c2.dead():
        print(c2.getname(), 'is the victor')
        victor = "B"

    elif c2.dead() and not c1.dead():
        print(c1.getname(), 'is the victor')
        victor = "A"
        
    else:
        print('Draw')             

    print('Final stats') 
    print('Number of Turns:', turn_count)
    print(c1.getname(), c1.printstat())
    print(c2.getname(), c2.printstat())
    return victor




# Now we can simulate the battle 1000 times

# simulate
c_Bvictor = 0
c_Avictor = 0

i = 1
while i <= 1000 :
    i += 1
    # Input the character data
    c1 = Character('Berserker', 5000, 400, 0.20, 2.0,  1, 0.000)
    c2 = Character('Paladin'  , 6000, 300, 0.10, 1.5,  0, 0.030)

    
    whowin = sim_battle(c1, c2)
    if whowin == "A":
        c_Avictor += 1
    else:
        c_Bvictor += 1

print("________________________________")
print("Berserker vs. Paladin results for 1000 battles:")
print("Berserker won:", c_Avictor)
print("Paladin won:", c_Bvictor)
# Out:
# Berserker is the victor
# Final stats
# Number of Turns: 28
# Berserker (800.0, 400, 0.2, 2.0)
# Paladin (-57.718524049144264, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 24
# Berserker (2300.0, 400, 0.2, 2.0)
# Paladin (-237.29523505604158, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 30
# Berserker (-250.0, 400, 0.2, 2.0)
# Paladin (2564.086101355195, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 28
# Berserker (-250.0, 400, 0.2, 2.0)
# Paladin (1876.4773150037054, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 29
# Berserker (200.0, 400, 0.2, 2.0)
# Paladin (-41.48436342635398, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 27
# Berserker (-100.0, 400, 0.2, 2.0)
# Paladin (1326.0103637280372, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 29
# Berserker (-400.0, 400, 0.2, 2.0)
# Paladin (1024.2112818351752, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 24
# Berserker (-250.0, 400, 0.2, 2.0)
# Paladin (2807.326069824148, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 30
# Berserker (-100.0, 400, 0.2, 2.0)
# Paladin (920.8254595471008, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 21
# Berserker (3500.0, 400, 0.2, 2.0)
# Paladin (-18.677061164559973, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 26
# Berserker (2150.0, 400, 0.2, 2.0)
# Paladin (-15.77215990852551, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 30
# Berserker (200.0, 400, 0.2, 2.0)
# Paladin (-282.28563960414897, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 26
# Berserker (800.0, 400, 0.2, 2.0)
# Paladin (-530.1935393728173, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 28
# Berserker (2000.0, 400, 0.2, 2.0)
# Paladin (-447.6203294304367, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 31
# Berserker (800.0, 400, 0.2, 2.0)
# Paladin (-148.89802253904574, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 31
# Berserker (-100.0, 400, 0.2, 2.0)
# Paladin (460.31367157765294, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 25
# Berserker (800.0, 400, 0.2, 2.0)
# Paladin (-483.80122808511567, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 26
# Berserker (-100.0, 400, 0.2, 2.0)
# Paladin (3764.996651918873, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 32
# Berserker (-250.0, 400, 0.2, 2.0)
# Paladin (1508.2389449277262, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 27
# Berserker (-250.0, 400, 0.2, 2.0)
# Paladin (1783.6273692957366, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 29
# Berserker (-250.0, 400, 0.2, 2.0)
# Paladin (1116.1608280051234, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 29
# Berserker (
 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 37
# Berserker (200.0, 400, 0.2, 2.0)
# Paladin (-708.8268592029726, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 30
# Berserker (-100.0, 400, 0.2, 2.0)
# Paladin (210.30274881255457, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 29
# Berserker (-250.0, 400, 0.2, 2.0)
# Paladin (2465.753496461354, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 30
# Berserker (500.0, 400, 0.2, 2.0)
# Paladin (-36.83606908496921, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 27
# Berserker (-250.0, 400, 0.2, 2.0)
# Paladin (2600.3256328648386, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 22
# Berserker (2150.0, 400, 0.2, 2.0)
# Paladin (-267.3155530213278, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 25
# Berserker (1100.0, 400, 0.2, 2.0)
# Paladin (-392.0196737360204, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 21
# Berserker (3050.0, 400, 0.2, 2.0)
# Paladin (-326.5771250221362, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 32
# Berserker (950.0, 400, 0.2, 2.0)
# Paladin (-530.7469458407842, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 31
# Berserker (1100.0, 400, 0.2, 2.0)
# Paladin (-233.8325909796057, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 27
# Berserker (-400.0, 400, 0.2, 2.0)
# Paladin (978.7508756891314, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 28
# Berserker (-250.0, 400, 0.2, 2.0)
# Paladin (297.20494802073245, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 30
# Berserker (-250.0, 400, 0.2, 2.0)
# Paladin (1713.8825773551948, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 28
# Berserker (-100.0, 400, 0.2, 2.0)
# Paladin (2477.753496461354, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 30
# Berserker (-100.0, 400, 0.2, 2.0)
# Paladin (2241.0086843958507, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 28
# Berserker (-100.0, 400, 0.2, 2.0)
# Paladin (496.8724778223275, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 29
# Berserker (-100.0, 400, 0.2, 2.0)
# Paladin (1209.6942174944713, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 34
# Berserker (-100.0, 400, 0.2, 2.0)
# Paladin (258.7571483840461, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 31
# Berserker (350.0, 400, 0.2, 2.0)
# Paladin (-344.1932359937892, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 29
# Berserker (-250.0, 400, 0.2, 2.0)
# Paladin (1946.6854639063076, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 27
# Berserker (1400.0, 400, 0.2, 2.0)
# Paladin (-460.4460970079461, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 31
# Berserker (800.0, 400, 0.2, 2.0)
# Paladin (-554.0623734961225, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 28
# Berserker (1700.0, 400, 0.2, 2.0)
# Paladin (-225.76812302782128, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 31
# Berserker (500.0, 400, 0.2, 2.0)
# Paladin (-708.8936225450582, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 30
# Berserker (-250.0, 400, 0.2, 2.0)
# Paladin (527.7261013551947, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 32
# Berserker (200.0, 400, 0.2, 2.0)
# Paladin (-229.67599326822153, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 24
# Berserker (2600.0, 400, 0.2, 2.0)
# Paladin (-347.08780182506905, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 29
# Berserker (1550.0, 400, 0.2, 2.0)
# Paladin (-648.1612185379536, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 32
# Berserker (-250.0, 400, 0.2, 2.0)
# Paladin (199.79256498577945, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 21
# Berserker (-100.0, 400, 0.2, 2.0)
# Paladin (4831.9901217999995, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 31
# Berserker (350.0, 400, 0.2, 2.0)
# Paladin (-423.54930332617533, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 20
# Berserker (2900.0, 400, 0.2, 2.0)
# Paladin (-194.79997222844483, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 33
# Berserker (50.0, 400, 0.2, 2.0)
# Paladin (-676.0244650546612, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 29
# Berserker (200.0, 400, 0.2, 2.0)
# Paladin (-482.44637381145185, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 28
# Berserker (350.0, 400, 0.2, 2.0)
# Paladin (-522.5672268976675, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 30
# Berserker (-250.0, 400, 0.2, 2.0)
# Paladin (77.79384654747525, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 31
# Berserker (650.0, 400, 0.2, 2.0)
# Paladin (-185.18976688443252, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 30
# Berserker (1400.0, 400, 0.2, 2.0)
# Paladin (-292.2828160963645, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 30
# Berserker (-100.0, 400, 0.2, 2.0)
# Paladin (1004.6486843958508, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 21
# Berserker (2450.0, 400, 0.2, 2.0)
# Paladin (-258.60983126910196, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 27
# Berserker (1100.0, 400, 0.2, 2.0)
# Paladin (-122.46699065557073, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 28
# Berserker (-100.0, 400, 0.2, 2.0)
# Paladin (2370.2849480207324, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 27
# Berserker (1550.0, 400, 0.2, 2.0)
# Paladin (-238.04795905604163, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 25
# Berserker (-250.0, 400, 0.2, 2.0)
# Paladin (3364.996651918873, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 32
# Berserker (500.0, 400, 0.2, 2.0)
# Paladin (-185.18976688443252, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 26
# Berserker (-100.0, 400, 0.2, 2.0)
# Paladin (2585.99700530649, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 29
# Berserker (-100.0, 400, 0.2, 2.0)
# Paladin (1371.515271763009, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 30
# Berserker (-100.0, 400, 0.2, 2.0)
# Paladin (1149.7485843684226, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 25
# Berserker (2300.0, 400, 0.2, 2.0)
# Paladin (-14.61240991979463, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 27
# Berserker (-250.0, 400, 0.2, 2.0)
# Paladin (1455.5732294091317, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 31
# Berserker (-100.0, 400, 0.2, 2.0)
# Paladin (1763.38776578425, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 34
# Berserker (500.0, 400, 0.2, 2.0)
# Paladin (-323.4823875757015, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 27
# Berserker (-100.0, 400, 0.2, 2.0)
# Paladin (1241.7534964613544, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 31
# Berserker (-250.0, 400, 0.2, 2.0)
# Paladin (1216.5043990152249, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 26
# Berserker (-100.0, 400, 0.2, 2.0)
# Paladin (1685.1965755864899, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 28
# Berserker (-250.0, 400, 0.2, 2.0)
# Paladin (1752.7688501131356, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 26
# Berserker (1400.0, 400, 0.2, 2.0)
# Paladin (-80.29962406262064, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 30
# Berserker (350.0, 400, 0.2, 2.0)
# Paladin (-1539.619406386486, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 31
# Berserker (-100.0, 400, 0.2, 2.0)
# Paladin (529.5972959869749, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 22
# Berserker (-250.0, 400, 0.2, 2.0)
# Paladin (3981.7865978, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 26
# Berserker (-100.0, 400, 0.2, 2.0)
# Paladin (3287.3757333072717, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 31
# Berserker (-250.0, 400, 0.2, 2.0)
# Paladin (820.5008056573795, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 27
# Berserker (1100.0, 400, 0.2, 2.0)
# Paladin (-70.0591249847754, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 27
# Berserker (1100.0, 400, 0.2, 2.0)
# Paladin (-26.98065242234702, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 27
# Berserker (-250.0, 400, 0.2, 2.0)
# Paladin (3040.8557514764384, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 28
# Berserker (-400.0, 400, 0.2, 2.0)
# Paladin (1615.5499724613537, 300, 0.1, 1.5)
# Berserker is the victor
# Final stats
# Number of Turns: 30
# Berserker (50.0, 400, 0.2, 2.0)
# Paladin (-158.69884835239884, 300, 0.1, 1.5)
# Paladin is the victor
# Final stats
# Number of Turns: 28
# Berserker (-100.0, 400, 0.2, 2.0)
# Paladin (1162.809919897545, 300, 0.1, 1.5)
# ________________________________
# Berserker vs. Paladin results for 1000 battles:
# Berserker won: 563
# Paladin won: 437
